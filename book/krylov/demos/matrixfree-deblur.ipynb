# %% [markdown]
# # Deblurring an image

# %%
using FundamentalsNumericalComputation

# %% [markdown]
# We repeat the earlier process to blur the original image $X$ to get $Z$.

# %%
img = testimage("mandrill");
m,n = size(img)
X = @. Float64(Gray(img))

B = spdiagm(0=>fill(0.5,m),1=>fill(0.25,m-1),-1=>fill(0.25,m-1));
C = spdiagm(0=>fill(0.5,n),1=>fill(0.25,n-1),-1=>fill(0.25,n-1));
blur = X -> B^12 * X * C^12;
Z = blur(X);
Gray.(Z)
# Out:
# 512×512 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0314484)  …  Gray{Float64}(0.0400561)
#  Gray{Float64}(0.0589383)     Gray{Float64}(0.0739199)
#  Gray{Float64}(0.0799305)     Gray{Float64}(0.0984714)
#  Gray{Float64}(0.0937928)     Gray{Float64}(0.114408)
#  Gray{Float64}(0.101263)      Gray{Float64}(0.124432)
#  Gray{Float64}(0.103572)   …  Gray{Float64}(0.130755)
#  Gray{Float64}(0.101936)      Gray{Float64}(0.133976)
#  Gray{Float64}(0.097568)      Gray{Float64}(0.133835)
#  Gray{Float64}(0.0918858)     Gray{Float64}(0.130666)
#  Gray{Float64}(0.0865127)     Gray{Float64}(0.126085)
#  Gray{Float64}(0.0829619)  …  Gray{Float64}(0.122412)
#  Gray{Float64}(0.0821783)     Gray{Float64}(0.121466)
#  Gray{Float64}(0.0842236)     Gray{Float64}(0.123769)
#  ⋮                         ⋱
#  Gray{Float64}(0.173392)   …  Gray{Float64}(0.09941)
#  Gray{Float64}(0.171059)      Gray{Float64}(0.10102)
#  Gray{Float64}(0.168325)      Gray{Float64}(0.102677)
#  Gray{Float64}(0.16557)       Gray{Float64}(0.104284)
#  Gray{Float64}(0.162978)      Gray{Float64}(0.105582)
#  Gray{Float64}(0.160241)   …  Gray{Float64}(0.106)
#  Gray{Float64}(0.156255)      Gray{Float64}(0.104541)
#  Gray{Float64}(0.148978)      Gray{Float64}(0.0998276)
#  Gray{Float64}(0.135733)      Gray{Float64}(0.0903943)
#  Gray{Float64}(0.114099)      Gray{Float64}(0.0752087)
#  Gray{Float64}(0.0830822)  …  Gray{Float64}(0.0541862)
#  Gray{Float64}(0.0439106)     Gray{Float64}(0.028418)

# %% [markdown]
# Now we imagine that $X$ is unknown and that the blurred $Z$ is given. We want to invert the blur transformation using the transformation itself. But we have to translate between vectors and images each time.

# %%
# vec (built-in) converts matrix to vector
unvec = z -> reshape(z,m,n)  # convert vector to matrix

T = LinearMap(x -> vec(blur(unvec(x))),m*n);

# %% [markdown]
# The blurring operators are symmetric, so we apply `minres` to the composite blurring transformation `T`.

# %%
y = minres(T,vec(Z),maxiter=50,reltol=1e-5);
Y = unvec(@.max(0,min(1,y)));

plot(Gray.(X),layout=2,subplot=1,title="Original",aspect_ratio=1)
plot!(Gray.(Y),layout=2,subplot=2,title="Deblurred",aspect_ratio=1)
